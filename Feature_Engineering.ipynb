# %% [markdown]
# **Feature Engineering Assignment**
#
# 1. What is a parameter?
# -> A parameter is a value that is learned from the data during the training of a machine learning model. It defines the model's skill on the problem.
#
# 2. What is correlation?
# -> Correlation is a statistical measure that expresses the extent to which two variables are linearly related, meaning they change together at a constant rate.
# What does negative correlation mean?
# -> Negative correlation means that as one variable increases, the other variable tends to decrease, and vice versa.
#
# 3. Define Machine Learning. What are the main components in Machine Learning?
# -> Machine Learning is a field of artificial intelligence that enables computer systems to learn from data without being explicitly programmed. The main components are: 1. Data, 2. Model, 3. Learning Algorithm.
#
# 4. How does loss value help in determining whether the model is good or not?
# -> Loss value quantifies the error between the model's predictions and the actual values. A lower loss value generally indicates a better-performing model.
#
# 5. What are continuous and categorical variables?
# -> Continuous variables can take on any value within a range (e.g., height, temperature). Categorical variables represent distinct groups or categories (e.g., color, gender).
#
# 6. How do we handle categorical variables in Machine Learning? What are the common techniques?
# -> Categorical variables are often converted into numerical representations. Common techniques include: 1. One-Hot Encoding, 2. Label Encoding.
#
# 7. What do you mean by training and testing a dataset?
# -> Training a dataset involves using a portion of the data to teach the machine learning model to identify patterns. Testing a dataset involves evaluating the trained model's performance on unseen data to assess its generalization ability.
#
# 8. What is sklearn.preprocessing?
# -> sklearn.preprocessing is a module in the scikit-learn library in Python that provides functions for data preprocessing and feature engineering, such as scaling, encoding, and splitting data.
#
# 9. What is a Test set?
# -> A test set is a portion of the dataset that is held back during the model training process and used solely to evaluate the final performance of the trained model on unseen data.
#
# 10. How do we split data for model fitting (training and testing) in Python?
# -> We typically use the train_test_split function from sklearn.model_selection in Python to split data into training and testing sets.
#
# How do you approach a Machine Learning problem?
# -> A common approach involves: 1. Defining the problem, 2. Collecting and preparing data, 3. Choosing a model, 4. Training the model, 5. Evaluating the model, 6. Tuning the model (if needed), 7. Deploying the model.
#
# 11. Why do we have to perform EDA before fitting a model to the data?
# -> Exploratory Data Analysis (EDA) helps us understand the data's characteristics, identify patterns, detect anomalies, and gain insights that can guide feature engineering and model selection, leading to better model performance.
#
# 12. What is correlation?
# -> Correlation is a statistical measure that expresses the extent to which two variables are linearly related.
#
# 13. What does negative correlation mean?
# -> Negative correlation means that as one variable increases, the other variable tends to decrease.
#
# 14. How can you find correlation between variables in Python?
# -> You can find the correlation between variables in Python using methods like df.corr() in pandas, which calculates the pairwise correlation of columns in a DataFrame.
#
# 15. What is causation? Explain difference between correlation and causation with an example.
# -> Causation means that one event directly causes another event. Correlation indicates a relationship between variables, but not necessarily a cause-and-effect relationship.
#
# Example: Ice cream sales and crime rates might be positively correlated (both increase in summer). However, ice cream sales don't cause crime, and crime doesn't cause ice cream sales. A confounding factor like warmer weather likely influences both.
#
# 16. What is an Optimizer? What are different types of optimizers? Explain each with an example.
# An optimizer is an algorithm used to adjust the parameters of a machine learning model during training to minimize the loss function.
#
# Gradient Descent: Iteratively moves towards the minimum of the loss function by calculating the gradient. Example: Imagine rolling a ball down a hill; gradient descent is like the ball following the steepest slope.
# Adam (Adaptive Moment Estimation): Combines the benefits of AdaGrad and RMSProp, adapting the learning rate for each parameter based on the first and second moments of the gradients. Example: An intelligent ball that adjusts its speed and direction based on both the current slope and its past momentum.
# RMSProp (Root Mean Square Propagation): Adapts the learning rate for each parameter by dividing it by the exponentially decaying average of squared gradients. Example: A ball that slows down its descent in steeper areas to avoid overshooting the minimum.
# 17. What is sklearn.linear_model ?
# sklearn.linear_model is a module in scikit-learn that implements various linear models for regression and classification tasks, such as Linear Regression, Logistic Regression, and Ridge Regression.
#
# 18. What does model.fit() do? What arguments must be given?
# model.fit() is a method used to train a machine learning model. It learns the parameters of the model from the training data. The primary arguments are typically:
#
# X_train: The training data features.
# y_train: The corresponding training data target variable.
# 19. What does model.predict() do? What arguments must be given?
# model.predict() is a method used to generate predictions using a trained machine learning model on new, unseen data. The primary argument is:
#
# X_test: The test data features for which predictions are to be made.
# 20. What are continuous and categorical variables?
# Continuous variables can take on any value within a range. Categorical variables represent distinct groups or categories.
#
# 21. What is feature scaling? How does it help in Machine Learning?
# Feature scaling is a preprocessing technique used to standardize or normalize the range of independent variables. It helps machine learning algorithms converge faster, prevents features with larger values from dominating, and improves the performance of distance-based algorithms.
#
# 22. How do we perform scaling in Python?
# We can perform scaling in Python using classes from sklearn.preprocessing, such as StandardScaler for standardization and MinMaxScaler for normalization.
#
# 23. What is sklearn.preprocessing?
# sklearn.preprocessing is a module in scikit-learn providing functions for data preprocessing and feature engineering.
#
# 24. How do we split data for model fitting (training and testing) in Python?
# We use the train_test_split function from sklearn.model_selection.
#
# 25. Explain data encoding?
# Data encoding is the process of converting categorical data into a numerical format that machine learning models can understand and process. Techniques like one-hot encoding and label encoding are common examples.
